# %% [markdown]
# # Data Exploration
#
# This notebook is for exploratory data analysis (EDA) of the PSL score prediction dataset.

# %%
import sys
from pathlib import Path

# Add src directory to path
sys.path.insert(0, str(Path('.').resolve().parent / 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from config.config import RAW_DATA_DIR, PROCESSED_DATA_DIR
from data.load_data import load_raw_data

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Data

# %%
# Load your raw data
# df = load_raw_data(RAW_DATA_DIR / 'your_data.csv')
# df.head()

# %% [markdown]
# ## Data Overview

# %%
# df.info()
# df.describe()

# %% [markdown]
# ## Data Visualization

# %%
# Create visualizations here
# plt.figure(figsize=(12, 6))
# plt.title('Title')
# plt.show()

# %% [markdown]
# ## Preprocessing

# %%
# from src.features.feature_engineering import handle_missing_values, create_features
# df_processed = handle_missing_values(df)
# df_processed = create_features(df_processed)
